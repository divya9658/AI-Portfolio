# %% [markdown]
# <a href="https://colab.research.google.com/github/divya9658/AI-Portfolio/blob/main/AI_DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the essential skills needed for successful AI implementation, from foundational to advanced:
#
# *   **Layer 1: Domain Expertise & Business Acumen:** Understanding the problem, business context, and identifying valuable AI applications.
# *   **Layer 2: Data Science & Machine Learning Fundamentals:** Proficiency in data analysis, statistics, core ML algorithms, and model development.
# *   **Layer 3: Software Engineering & MLOps:** Skills to build, deploy, manage, and scale AI models in production environments reliably.
# *   **Layer 4: Specialized AI Expertise:** Deep knowledge in specific AI fields like NLP, computer vision, reinforcement learning, or generative AI.
# *   **Layer 5: Leadership, Strategy & Ethics:** Guiding AI initiatives, ensuring responsible and ethical development, and driving strategic impact.
